# %% [markdown]
# # SPOT Kriging in 6 Dimensions: Nyström Approximation vs. Exact (Rosenbrock Function)
#
# This notebook demonstrates how to use the `Spot` class from `spotpython` with and without the Nyström approximation for Kriging surrogates on the 6-dimensional Rosenbrock function.
#
# We use a maximum of 100 function evaluations.

# %%
import numpy as np
from spotpython.fun.objectivefunctions import Analytical
from spotpython.spot import Spot
from spotpython.utils.init import fun_control_init, design_control_init, surrogate_control_init
# Out:
# Seed set to 123

# %% [markdown]
# ## Define the 6D Rosenbrock Function

# %%
# do not change, these are given by the organizers
dim = 6
lower = np.full(dim, -2)
upper = np.full(dim, 2)
fun = Analytical().fun_rosenbrock
fun_evals = 1000

# %% [markdown]
# ## Set up SPOT Controls

# %% [markdown]
# ## Regression and y as Infill Criterion

# %%
init_size = 12
use_nystrom = False
method = "regression"
infill_criterion = "y"
tolerance_x = 0.0
seed = 321
max_surrogate_points = 24
min_Lambda = -4
max_Lambda = 3
min_theta = -1
max_theta = 1
isotropic = False

# %%
fun_control = fun_control_init(
    lower=lower,
    upper=upper,
    fun_evals=fun_evals,
    max_time=60,
    seed=seed,
    show_progress=True,
    infill_criterion=infill_criterion,
    tolerance_x=tolerance_x,
    TENSORBOARD_CLEAN=True,
    tensorboard_log=True,
    acquisition_failure_strategy="mm",
)
design_control = design_control_init(init_size=init_size)
surrogate_control_exact = surrogate_control_init(use_nystrom=use_nystrom, method=method, max_surrogate_points=max_surrogate_points, min_Lambda=min_Lambda, max_Lambda=max_Lambda, min_theta=min_theta, max_theta=max_theta, isotropic=isotropic)
# Out:
# Seed set to 321
# Moving TENSORBOARD_PATH: runs/ to TENSORBOARD_PATH_OLD: runs_OLD/runs_2025_11_03_14_31_14_0
# Created spot_tensorboard_path: runs/spot_logs/000_p040025_2025-11-03_14-31-14 for SummaryWriter()

# %%
try:
    spot_exact_y = Spot(
        fun=fun,
        fun_control=fun_control,
        design_control=design_control,
        surrogate_control=surrogate_control_exact
    )
    spot_exact_y.run()
    exact_success_y = True
except Exception as e:
    print(f"Exact Kriging failed: {e}")
    exact_success_y = False
if exact_success_y:
    spot_exact_y.plot_progress(log_y=True, title="Exact Kriging Progress with y")
# Out:
# spotpython tuning: 45.355898844847545 [----------] 1.30%
# spotpython tuning: 39.27689246985392 [----------] 1.40%
# spotpython tuning: 39.27689246985392 [----------] 1.50%
# spotpython tuning: 39.27689246985392 [----------] 1.60%
# spotpython tuning: 14.210612708343556 [----------] 1.70%
# spotpython tuning: 14.210612708343556 [----------] 1.80%
# spotpython tuning: 14.210612708343556 [----------] 1.90%
# spotpython tuning: 14.210612708343556 [----------] 2.00%
# spotpython tuning: 14.210612708343556 [----------] 2.10%
# spotpython tuning: 14.210612708343556 [----------] 2.20%
# spotpython tuning: 14.210612708343556 [----------] 2.30%
# spotpython tuning: 14.210612708343556 [----------] 2.40%
# spotpython tuning: 14.210612708343556 [----------] 2.50%
# spotpython tuning: 14.210612708343556 [----------] 2.60%
# spotpython tuning: 14.210612708343556 [----------] 2.70%
# spotpython tuning: 14.210612708343556 [----------] 2.80%
# spotpython tuning: 14.210612708343556 [----------] 2.90%
# spotpython tuning: 14.210612708343556 [----------] 3.00%
# spotpython tuning: 14.210612708343556 [----------] 3.10%
# spotpython tuning: 14.210612708343556 [----------] 3.20%
# spotpython tuning: 14.210612708343556 [----------] 3.30%
# spotpython tuning: 14.210612708343556 [----------] 3.40%
# spotpython tuning: 14.210612708343556 [----------] 3.50%
# spotpython tuning: 14.210612708343556 [----------] 3.60%
# spotpython tuning: 14.210612708343556 [----------] 3.70%
# spotpython tuning: 14.210612708343556 [----------] 3.80%
# spotpython tuning: 14.210612708343556 [----------] 3.90%
# spotpython tuning: 14.210612708343556 [----------] 4.00%
# spotpython tuning: 14.210612708343556 [----------] 4.10%
# spotpython tuning: 14.210612708343556 [----------] 4.20%
# spotpython tuning: 14.210612708343556 [----------] 4.30%
# spotpython tuning: 14.210612708343556 [----------] 4.40%
# spotpython tuning: 14.210612708343556 [----------] 4.50%
# spotpython tuning: 14.210612708343556 [----------] 4.60%
# spotpython tuning: 14.210612708343556 [----------] 4.70%
# spotpython tuning: 14.210612708343556 [----------] 4.80%
# spotpython tuning: 14.210612708343556 [----------] 4.90%
# spotpython tuning: 14.210612708343556 [----------] 5.00%
# spotpython tuning: 14.210612708343556 [#---------] 5.10%
# spotpython tuning: 14.210612708343556 [#---------] 5.20%
# spotpython tuning: 14.210612708343556 [#---------] 5.30%
# spotpython tuning: 14.210612708343556 [#---------] 5.40%
# spotpython tuning: 14.210612708343556 [#---------] 5.50%
# spotpython tuning: 14.210612708343556 [#---------] 5.60%
# spotpython tuning: 14.210612708343556 [#---------] 5.70%
# spotpython tuning: 14.210612708343556 [#---------] 5.80%
# spotpython tuning: 14.210612708343556 [#---------] 5.90%
# spotpython tuning: 14.210612708343556 [#---------] 6.00%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 14.210612708343556 [#---------] 6.10%
# spotpython tuning: 14.210612708343556 [#---------] 6.20%
# spotpython tuning: 14.210612708343556 [#---------] 6.30%
# spotpython tuning: 14.210612708343556 [#---------] 6.40%
# spotpython tuning: 14.210612708343556 [#---------] 6.50%
# spotpython tuning: 14.210612708343556 [#---------] 6.60%
# spotpython tuning: 14.210612708343556 [#---------] 6.70%
# spotpython tuning: 14.210612708343556 [#---------] 6.80%
# spotpython tuning: 14.210612708343556 [#---------] 6.90%
# spotpython tuning: 14.210612708343556 [#---------] 7.00%
# spotpython tuning: 14.210612708343556 [#---------] 7.10%
# spotpython tuning: 14.210612708343556 [#---------] 7.20%
# spotpython tuning: 14.210612708343556 [#---------] 7.30%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 14.210612708343556 [#---------] 7.40%
# spotpython tuning: 14.210612708343556 [#---------] 7.50%
# spotpython tuning: 14.210612708343556 [#---------] 7.60%
# spotpython tuning: 14.210612708343556 [#---------] 7.70%
# spotpython tuning: 14.210612708343556 [#---------] 7.80%
# spotpython tuning: 14.210612708343556 [#---------] 7.90%
# spotpython tuning: 14.210612708343556 [#---------] 8.00%
# spotpython tuning: 14.210612708343556 [#---------] 8.10%
# spotpython tuning: 14.210612708343556 [#---------] 8.20%
# spotpython tuning: 14.210612708343556 [#---------] 8.30%
# spotpython tuning: 14.210612708343556 [#---------] 8.40%
# spotpython tuning: 14.210612708343556 [#---------] 8.50%
# spotpython tuning: 14.210612708343556 [#---------] 8.60%
# spotpython tuning: 14.210612708343556 [#---------] 8.70%
# spotpython tuning: 14.210612708343556 [#---------] 8.80%
# spotpython tuning: 14.210612708343556 [#---------] 8.90%
# spotpython tuning: 14.210612708343556 [#---------] 9.00%
# spotpython tuning: 14.210612708343556 [#---------] 9.10%
# spotpython tuning: 14.210612708343556 [#---------] 9.20%
# spotpython tuning: 14.210612708343556 [#---------] 9.30%
# spotpython tuning: 14.210612708343556 [#---------] 9.40%
# spotpython tuning: 14.210612708343556 [#---------] 9.50%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 14.210612708343556 [#---------] 9.60%
# spotpython tuning: 14.210612708343556 [#---------] 9.70%
# spotpython tuning: 14.210612708343556 [#---------] 9.80%
# spotpython tuning: 14.210612708343556 [#---------] 9.90%
# spotpython tuning: 14.210612708343556 [#---------] 10.00%
# spotpython tuning: 14.210612708343556 [#---------] 10.10%
# spotpython tuning: 14.210612708343556 [#---------] 10.20%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 14.210612708343556 [#---------] 10.30%
# spotpython tuning: 14.210612708343556 [#---------] 10.40%
# spotpython tuning: 14.210612708343556 [#---------] 10.50%
# spotpython tuning: 14.210612708343556 [#---------] 10.60%
# spotpython tuning: 14.029776938097827 [#---------] 10.70%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 14.029776938097827 [#---------] 10.80%
# spotpython tuning: 14.029776938097827 [#---------] 10.90%
# spotpython tuning: 14.029776938097827 [#---------] 11.00%
# spotpython tuning: 14.029776938097827 [#---------] 11.10%
# spotpython tuning: 14.029776938097827 [#---------] 11.20%
# spotpython tuning: 14.029776938097827 [#---------] 11.30%
# spotpython tuning: 14.029776938097827 [#---------] 11.40%
# spotpython tuning: 14.029776938097827 [#---------] 11.50%
# spotpython tuning: 14.029776938097827 [#---------] 11.60%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 14.029776938097827 [#---------] 11.70%
# spotpython tuning: 14.029776938097827 [#---------] 11.80%
# spotpython tuning: 14.029776938097827 [#---------] 11.90%
# spotpython tuning: 14.029776938097827 [#---------] 12.00%
# spotpython tuning: 14.029776938097827 [#---------] 12.10%
# spotpython tuning: 14.029776938097827 [#---------] 12.20%
# spotpython tuning: 12.610556579002761 [#---------] 12.30%
# spotpython tuning: 12.610556579002761 [#---------] 12.40%
# spotpython tuning: 12.610556579002761 [#---------] 12.50%
# spotpython tuning: 12.610556579002761 [#---------] 12.60%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 12.610556579002761 [#---------] 12.70%
# spotpython tuning: 12.610556579002761 [#---------] 12.80%
# spotpython tuning: 12.610556579002761 [#---------] 12.90%
# spotpython tuning: 12.610556579002761 [#---------] 13.00%
# spotpython tuning: 12.610556579002761 [#---------] 13.10%
# spotpython tuning: 12.610556579002761 [#---------] 13.20%
# spotpython tuning: 12.610556579002761 [#---------] 13.30%
# spotpython tuning: 12.610556579002761 [#---------] 13.40%
# spotpython tuning: 12.610556579002761 [#---------] 13.50%
# spotpython tuning: 12.610556579002761 [#---------] 13.60%
# spotpython tuning: 12.610556579002761 [#---------] 13.70%
# spotpython tuning: 12.610556579002761 [#---------] 13.80%
# spotpython tuning: 12.610556579002761 [#---------] 13.90%
# spotpython tuning: 12.610556579002761 [#---------] 14.00%
# spotpython tuning: 12.610556579002761 [#---------] 14.10%
# spotpython tuning: 12.610556579002761 [#---------] 14.20%
# spotpython tuning: 12.610556579002761 [#---------] 14.30%
# spotpython tuning: 12.610556579002761 [#---------] 14.40%
# spotpython tuning: 12.610556579002761 [#---------] 14.50%
# spotpython tuning: 12.610556579002761 [#---------] 14.60%
# spotpython tuning: 12.610556579002761 [#---------] 14.70%
# spotpython tuning: 12.610556579002761 [#---------] 14.80%
# spotpython tuning: 12.610556579002761 [#---------] 14.90%
# spotpython tuning: 12.610556579002761 [##--------] 15.00%
# spotpython tuning: 12.610556579002761 [##--------] 15.10%
# spotpython tuning: 12.610556579002761 [##--------] 15.20%
# spotpython tuning: 12.610556579002761 [##--------] 15.30%
# spotpython tuning: 12.610556579002761 [##--------] 15.40%
# spotpython tuning: 12.610556579002761 [##--------] 15.50%
# spotpython tuning: 12.610556579002761 [##--------] 15.60%
# spotpython tuning: 12.610556579002761 [##--------] 15.70%
# spotpython tuning: 12.610556579002761 [##--------] 15.80%
# spotpython tuning: 12.610556579002761 [##--------] 15.90%
# spotpython tuning: 12.610556579002761 [##--------] 16.00%
# spotpython tuning: 12.610556579002761 [##--------] 16.10%
# spotpython tuning: 12.610556579002761 [##--------] 16.20%
# spotpython tuning: 12.610556579002761 [##--------] 16.30%
# spotpython tuning: 12.610556579002761 [##--------] 16.40%
# spotpython tuning: 12.610556579002761 [##--------] 16.50%
# spotpython tuning: 12.610556579002761 [##--------] 16.60%
# spotpython tuning: 12.610556579002761 [##--------] 16.70%
# spotpython tuning: 12.610556579002761 [##--------] 16.80%
# spotpython tuning: 12.610556579002761 [##--------] 16.90%
# spotpython tuning: 12.610556579002761 [##--------] 17.00%
# spotpython tuning: 12.610556579002761 [##--------] 17.10%
# spotpython tuning: 12.610556579002761 [##--------] 17.20%
# spotpython tuning: 12.610556579002761 [##--------] 17.30%
# spotpython tuning: 12.610556579002761 [##--------] 17.40%
# spotpython tuning: 12.610556579002761 [##--------] 17.50%
# spotpython tuning: 12.610556579002761 [##--------] 17.60%
# Using mmphi minimizing point as fallback.
# spotpython tuning: 12.610556579002761 [##--------] 17.70%
# spotpython tuning: 12.610556579002761 [##--------] 17.80%
# spotpython tuning: 12.610556579002761 [##--------] 17.90%
# spotpython tuning: 12.610556579002761 [##--------] 18.00%
# spotpython tuning: 12.610556579002761 [##--------] 18.10%
# spotpython tuning: 12.610556579002761 [##--------] 18.20%
# spotpython tuning: 12.610556579002761 [##--------] 18.30%
# spotpython tuning: 12.610556579002761 [##--------] 18.40%
# spotpython tuning: 12.610556579002761 [##--------] 18.50%
# spotpython tuning: 12.610556579002761 [##--------] 18.60%
# spotpython tuning: 12.610556579002761 [##--------] 18.70%
# spotpython tuning: 12.610556579002761 [##--------] 18.80%
# spotpython tuning: 12.610556579002761 [##--------] 18.90%
# spotpython tuning: 12.610556579002761 [##--------] 19.00%
# spotpython tuning: 12.610556579002761 [##--------] 19.10%
# spotpython tuning: 12.610556579002761 [##--------] 19.20%
# spotpython tuning: 12.610556579002761 [##--------] 19.30%
# spotpython tuning: 12.610556579002761 [##--------] 19.40%
# spotpython tuning: 12.610556579002761 [##--------] 19.50%
# spotpython tuning: 12.610556579002761 [##--------] 19.60%
# spotpython tuning: 12.610556579002761 [##--------] 19.70%
# spotpython tuning: 12.610556579002761 [##--------] 19.80%
# spotpython tuning: 12.610556579002761 [##--------] 19.90%
# spotpython tuning: 12.610556579002761 [##--------] 20.00%
# spotpython tuning: 12.610556579002761 [##--------] 20.10%
# spotpython tuning: 12.610556579002761 [##--------] 20.20%
# spotpython tuning: 12.610556579002761 [##--------] 20.30%
# spotpython tuning: 12.610556579002761 [##--------] 20.40%
# spotpython tuning: 12.610556579002761 [##--------] 20.50%
# spotpython tuning: 12.610556579002761 [##--------] 20.60%
# spotpython tuning: 12.610556579002761 [##--------] 20.70%
# spotpython tuning: 12.610556579002761 [##--------] 20.80%
# spotpython tuning: 12.610556579002761 [##--------] 20.90%
# spotpython tuning: 12.610556579002761 [##--------] 21.00%
# spotpython tuning: 12.610556579002761 [##--------] 21.10%
# spotpython tuning: 12.610556579002761 [##--------] 21.20%
# spotpython tuning: 12.610556579002761 [##--------] 21.30%
# spotpython tuning: 12.610556579002761 [##--------] 21.40%
# spotpython tuning: 12.610556579002761 [##--------] 21.50%
# spotpython tuning: 12.610556579002761 [##--------] 21.60%
# spotpython tuning: 12.610556579002761 [##--------] 21.70%
# spotpython tuning: 12.610556579002761 [##--------] 21.80%
# spotpython tuning: 12.610556579002761 [##--------] 21.90%
# spotpython tuning: 12.610556579002761 [##--------] 22.00%
# spotpython tuning: 12.610556579002761 [##--------] 22.10%
# spotpython tuning: 12.610556579002761 [##--------] 22.20%
# spotpython tuning: 12.610556579002761 [##--------] 22.30%
# spotpython tuning: 12.610556579002761 [##--------] 22.40%
# spotpython tuning: 12.610556579002761 [##--------] 22.50%
# spotpython tuning: 12.610556579002761 [##--------] 22.60%
# spotpython tuning: 12.610556579002761 [##--------] 22.70%
# spotpython tuning: 12.610556579002761 [##--------] 22.80%
# spotpython tuning: 12.610556579002761 [##--------] 22.90%
# spotpython tuning: 12.610556579002761 [##--------] 23.00%
# spotpython tuning: 12.610556579002761 [##--------] 23.10%
# spotpython tuning: 12.610556579002761 [##--------] 23.20%
# spotpython tuning: 12.610556579002761 [##--------] 23.30%
# spotpython tuning: 12.610556579002761 [##--------] 23.40%
# spotpython tuning: 12.610556579002761 [##--------] 23.50%
# spotpython tuning: 12.610556579002761 [##--------] 23.60%
# spotpython tuning: 12.610556579002761 [##--------] 23.70%
# spotpython tuning: 12.610556579002761 [##--------] 23.80%
# spotpython tuning: 12.610556579002761 [##--------] 23.90%
# spotpython tuning: 12.610556579002761 [##--------] 24.00%
# spotpython tuning: 12.610556579002761 [##--------] 24.10%
# spotpython tuning: 12.610556579002761 [##--------] 24.20%
# spotpython tuning: 12.610556579002761 [##--------] 24.30%
# spotpython tuning: 12.610556579002761 [##--------] 24.40%
# spotpython tuning: 12.610556579002761 [##--------] 24.50%
# spotpython tuning: 12.610556579002761 [##--------] 24.60%
# spotpython tuning: 12.610556579002761 [##--------] 24.70%
# spotpython tuning: 12.610556579002761 [##--------] 24.80%
# spotpython tuning: 12.610556579002761 [##--------] 24.90%
# spotpython tuning: 12.610556579002761 [##--------] 25.00%
# spotpython tuning: 12.610556579002761 [###-------] 25.10%
# spotpython tuning: 12.610556579002761 [###-------] 25.20%
# spotpython tuning: 12.610556579002761 [###-------] 25.30%
# spotpython tuning: 12.610556579002761 [###-------] 25.40%
# spotpython tuning: 12.610556579002761 [###-------] 25.50%
# spotpython tuning: 12.610556579002761 [###-------] 25.60%
# spotpython tuning: 12.610556579002761 [###-------] 25.70%
# spotpython tuning: 12.610556579002761 [###-------] 25.80%
# spotpython tuning: 12.610556579002761 [###-------] 25.90%
# spotpython tuning: 12.610556579002761 [###-------] 26.00%
# spotpython tuning: 12.610556579002761 [###-------] 26.10%
# spotpython tuning: 12.610556579002761 [###-------] 26.20%
# spotpython tuning: 12.610556579002761 [###-------] 26.30%
# spotpython tuning: 12.610556579002761 [###-------] 26.40%
# spotpython tuning: 12.610556579002761 [###-------] 26.50%
# spotpython tuning: 12.610556579002761 [###-------] 26.60%
# spotpython tuning: 12.610556579002761 [###-------] 26.70%
# spotpython tuning: 12.610556579002761 [###-------] 26.80%
# spotpython tuning: 12.610556579002761 [###-------] 26.90%
# spotpython tuning: 12.610556579002761 [###-------] 27.00%
# spotpython tuning: 12.610556579002761 [###-------] 27.10%
# spotpython tuning: 12.610556579002761 [###-------] 27.20%
# spotpython tuning: 12.610556579002761 [###-------] 27.30%
# spotpython tuning: 12.610556579002761 [###-------] 27.40%
# spotpython tuning: 12.610556579002761 [###-------] 27.50%
# spotpython tuning: 12.610556579002761 [###-------] 27.60%
# spotpython tuning: 12.610556579002761 [###-------] 27.70%
# spotpython tuning: 12.610556579002761 [###-------] 27.80%
# spotpython tuning: 12.610556579002761 [###-------] 27.90%
# spotpython tuning: 12.610556579002761 [###-------] 28.00%
# spotpython tuning: 12.610556579002761 [###-------] 28.10%
# spotpython tuning: 12.610556579002761 [###-------] 28.20%
# spotpython tuning: 12.610556579002761 [###-------] 28.30%
# spotpython tuning: 12.610556579002761 [###-------] 28.40%
# spotpython tuning: 12.610556579002761 [###-------] 28.50%
# spotpython tuning: 12.610556579002761 [###-------] 28.60%
# spotpython tuning: 12.610556579002761 [###-------] 28.70%
# spotpython tuning: 12.610556579002761 [###-------] 28.80%
# spotpython tuning: 12.610556579002761 [###-------] 28.90%
# spotpython tuning: 12.610556579002761 [###-------] 29.00%
# spotpython tuning: 12.610556579002761 [###-------] 29.10%
# spotpython tuning: 12.610556579002761 [###-------] 29.20%
# spotpython tuning: 12.610556579002761 [###-------] 29.30%
# spotpython tuning: 12.610556579002761 [###-------] 29.40%
# spotpython tuning: 12.610556579002761 [###-------] 29.50%
# spotpython tuning: 12.610556579002761 [###-------] 29.60%
# spotpython tuning: 12.610556579002761 [###-------] 29.70%
# spotpython tuning: 12.610556579002761 [###-------] 29.80%
# spotpython tuning: 12.610556579002761 [###-------] 29.90%
# spotpython tuning: 12.610556579002761 [###-------] 30.00%
# spotpython tuning: 12.610556579002761 [###-------] 30.10%
# spotpython tuning: 12.610556579002761 [###-------] 30.20%
# spotpython tuning: 12.610556579002761 [###-------] 30.30%
# spotpython tuning: 12.610556579002761 [###-------] 30.40%
# spotpython tuning: 12.610556579002761 [###-------] 30.50%
# spotpython tuning: 12.610556579002761 [###-------] 30.60%
# spotpython tuning: 12.610556579002761 [###-------] 30.70%
# spotpython tuning: 12.610556579002761 [###-------] 30.80%
# spotpython tuning: 12.610556579002761 [###-------] 30.90%
# spotpython tuning: 12.610556579002761 [###-------] 31.00%
# spotpython tuning: 12.610556579002761 [###-------] 31.10%
# spotpython tuning: 12.610556579002761 [###-------] 31.20%
# spotpython tuning: 12.610556579002761 [###-------] 31.30%
# spotpython tuning: 12.610556579002761 [###-------] 31.40%
# spotpython tuning: 12.610556579002761 [###-------] 31.50%
# spotpython tuning: 12.610556579002761 [###-------] 31.60%
# spotpython tuning: 12.610556579002761 [###-------] 31.70%
# spotpython tuning: 12.610556579002761 [###-------] 31.80%
# spotpython tuning: 12.610556579002761 [###-------] 31.90%
# spotpython tuning: 12.610556579002761 [###-------] 32.00%
# spotpython tuning: 12.610556579002761 [###-------] 32.10%
# spotpython tuning: 12.610556579002761 [###-------] 32.20%
# spotpython tuning: 12.610556579002761 [###-------] 32.30%
# spotpython tuning: 12.610556579002761 [###-------] 32.40%
# spotpython tuning: 12.610556579002761 [###-------] 32.50%
# spotpython tuning: 12.610556579002761 [###-------] 32.60%
# spotpython tuning: 12.610556579002761 [###-------] 32.70%
# spotpython tuning: 12.610556579002761 [###-------] 32.80%
# spotpython tuning: 12.610556579002761 [###-------] 32.90%

# %% [markdown]
# ## Regression  and  Expected Improvement as Infill Criterion

# %%
infill_criterion = "ei"

# %%
fun_control = fun_control_init(
    lower=lower,
    upper=upper,
    fun_evals=fun_evals,
    seed=seed,
    show_progress=True,
    infill_criterion=infill_criterion,
    tolerance_x=tolerance_x,
    TENSORBOARD_CLEAN=False,
    tensorboard_log=True
)
design_control = design_control_init(init_size=init_size)
surrogate_control_exact = surrogate_control_init(use_nystrom=use_nystrom, method=method,min_Lambda=min_Lambda, max_Lambda=max_Lambda, min_theta=min_theta, max_theta=max_theta, isotropic=isotropic)

# %%
try:
    spot_exact_ei = Spot(
        fun=fun,
        fun_control=fun_control,
        design_control=design_control,
        surrogate_control=surrogate_control_exact
    )
    spot_exact_ei.run()
    exact_success_ei = True
except Exception as e:
    print(f"Exact Kriging failed: {e}")
    exact_success_ei = False
if exact_success_ei:
    spot_exact_ei.plot_progress(log_y=False, title="Exact Kriging Progress with EI")

# %% [markdown]
# ## Regression and y with Nyström Kriging

# %%
use_nystrom = True
nystrom_m = 5
infill_criterion = "y"

# %%
fun_control = fun_control_init(
    lower=lower,
    upper=upper,
    fun_evals=fun_evals,
    seed=seed,
    show_progress=True,
    infill_criterion=infill_criterion,
    tolerance_x=tolerance_x,
    TENSORBOARD_CLEAN=False,
    tensorboard_log=True
)
design_control = design_control_init(init_size=init_size)
surrogate_control_nystrom = surrogate_control_init(use_nystrom=use_nystrom, nystrom_m=nystrom_m, method=method, min_Lambda=min_Lambda, max_Lambda=max_Lambda, min_theta=min_theta, max_theta=max_theta, isotropic=isotropic)

# %%
spot_nystrom_y = Spot(
    fun=fun,
    fun_control=fun_control,
    design_control=design_control,
    surrogate_control=surrogate_control_nystrom
)
spot_nystrom_y.run()
spot_nystrom_y.plot_progress(log_y=False, title="Nystrom Kriging Progress with y")

# %% [markdown]
# ## Regression and ei with Nyström Kriging

# %%
infill_criterion = "ei"

# %%
fun_control = fun_control_init(
    lower=lower,
    upper=upper,
    fun_evals=fun_evals,
    seed=seed,
    show_progress=True,
    infill_criterion=infill_criterion,
    tolerance_x=tolerance_x,
    TENSORBOARD_CLEAN=False,
    tensorboard_log=True
)
design_control = design_control_init(init_size=init_size)
surrogate_control_nystrom = surrogate_control_init(use_nystrom=use_nystrom, nystrom_m=nystrom_m, method=method, min_Lambda=min_Lambda, max_Lambda=max_Lambda, min_theta=min_theta, max_theta=max_theta, isotropic=isotropic)

# %%
spot_nystrom_ei = Spot(
    fun=fun,
    fun_control=fun_control,
    design_control=design_control,
    surrogate_control=surrogate_control_nystrom
)
spot_nystrom_ei.run()
spot_nystrom_ei.plot_progress(log_y=False, title="Nystrom Kriging Progress with ei")

# %% [markdown]
# ## Compare Minimum Found

# %%
print(f"[6D] Exact Kriging y: min y = {spot_exact_y.min_y:.4f} at x = {spot_exact_y.min_X}")
print(f"[6D] Exact Kriging ei: min y = {spot_exact_ei.min_y:.4f} at x = {spot_exact_ei.min_X}")
print(f"[6D] Nyström Kriging y: min y = {spot_nystrom_y.min_y:.4f} at x = {spot_nystrom_y.min_X}")
print(f"[6D] Nyström Kriging ei: min y = {spot_nystrom_ei.min_y:.4f} at x = {spot_nystrom_ei.min_X}")

# %%
spot_exact_y.plot_important_hyperparameter_contour(max_imp=3)
