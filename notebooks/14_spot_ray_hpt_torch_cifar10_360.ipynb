# %% [raw]
# ---
# title: "pytorch Hyperparameter Tuning with SPOT: Comparison with ray tuner on cifar10"
# format: html
# ---

# %%
MAX_TIME = 360
INIT_SIZE = 20
DEVICE = "cpu" # "cuda:0"

# %%
import pickle
import socket
from datetime import datetime
from dateutil.tz import tzlocal
start_time = datetime.now(tzlocal())
HOSTNAME = socket.gethostname().split(".")[0]
experiment_name = '12-torch' + "_" + HOSTNAME + "_" + str(MAX_TIME) + "min_" + str(INIT_SIZE) + "init_" + str(start_time).split(".", 1)[0].replace(' ', '_')
experiment_name = experiment_name.replace(':', '-')
experiment_name
# Out:
# '12-torch_p040025_360min_20init_2023-05-07_23-36-22'

# %% [markdown]
# # Chapter 14: Sequential Parameter Optimization Compared to Ray Tune
# ## Hyperparameter Tuning: pytorch wth cifar10 Data

# %% [markdown]
# * This notebook exemplifies hyperparameter tuning with SPOT (spotPython).
# * The hyperparameter software SPOT was developed in R (statistical programming language), see Open Access book "Hyperparameter Tuning for Machine and Deep Learning with R - A Practical Guide", available here: [https://link.springer.com/book/10.1007/978-981-19-5170-1](https://link.springer.com/book/10.1007/978-981-19-5170-1).

# %%
pip list | grep  "spot[RiverPython]"
# Out:
# spotPython                                0.0.62
# spotRiver                                 0.0.92
# Note: you may need to restart the kernel to use updated packages.

# %%
# import sys
# !{sys.executable} -m pip install --upgrade build
# !{sys.executable} -m pip install --upgrade --force-reinstall spotPython

# %%
from tabulate import tabulate
import copy
import warnings
import numbers
import json
import calendar
import math
import datetime as dt
import numpy as np
from math import inf
import pandas as pd

from scipy.optimize import differential_evolution

import matplotlib.pyplot as plt

from functools import partial

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchvision import datasets
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor

from spotPython.spot import spot
from spotPython.hyperparameters.values import (
    add_core_model_to_fun_control,
    assign_values,
    convert_keys,
    get_bound_values,
    get_default_hyperparameters_for_core_model,
    get_default_values,
    get_dict_with_levels_and_types,
    get_values_from_dict,
    get_var_name,
    get_var_type,
    iterate_dict_values,
    modify_hyper_parameter_levels,
    modify_hyper_parameter_bounds,
    replace_levels_with_positions,
    return_conf_list_from_var_dict,
    get_one_core_model_from_X,
    transform_hyper_parameter_values,
    get_dict_with_levels_and_types,
    convert_keys,
    iterate_dict_values,
)

from spotPython.utils.convert import class_for_name
from spotPython.utils.eda import (
    get_stars,
    gen_design_table)
from spotPython.utils.transform import transform_hyper_parameter_values

from spotPython.utils.convert import get_Xy_from_df
from spotPython.utils.init import fun_control_init
from spotPython.plot.validation import plot_cv_predictions, plot_roc, plot_confusion_matrix

from spotPython.data.torch_hyper_dict import TorchHyperDict
from spotPython.fun.hypertorch import HyperTorch

warnings.filterwarnings("ignore")

from spotPython.torch.netcifar10 import Net_CIFAR10

# %%
print(torch.__version__)
# Check that MPS is available
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print("MPS not available because the current PyTorch install was not "
              "built with MPS enabled.")
    else:
        print("MPS not available because the current MacOS version is not 12.3+ "
              "and/or you do not have an MPS-enabled device on this machine.")

else:
    mps_device = torch.device("mps")
    print("MPS device: ", mps_device)
# Out:
# 2.0.0
# MPS device:  mps

# %% [markdown]
# ## 0. Initialization of the Empty `fun_control` Dictionary

# %%
fun_control = fun_control_init()

# %% [markdown]
# ## 1. Load CIFAR Data

# %% [markdown]
# The data loading is implemented as in the Section "Data loaders" in the PyTorch tutorial [Hyperparameter Tuning  with Ray Tune](https://pytorch.org/tutorials/beginner/hyperparameter_tuning_tutorial.html).

# %%
def load_data(data_dir="./data"):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(
        root=data_dir, train=True, download=True, transform=transform)

    testset = torchvision.datasets.CIFAR10(
        root=data_dir, train=False, download=True, transform=transform)

    return trainset, testset

# %%
train, test = load_data()
train.data.shape, test.data.shape
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
n_samples = len(train)
# add the dataset to the fun_control
fun_control.update({"data": None, # dataset,
               "train": train,
               "test": test,
               "n_samples": n_samples,
               "target_column": None})

# %% [markdown]
# ## 2. Specification of the Preprocessing Model
#
# Because the Ray Tune hyperparameter tuning does not use a preprocessing model, the preprocessing model is set to `None` here.

# %%
# categorical_columns = []
# one_hot_encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
# prep_model = ColumnTransformer(
#         transformers=[
#             ("categorical", one_hot_encoder, categorical_columns),
#         ],
#         remainder=StandardScaler(),
#     )
prep_model = None
fun_control.update({"prep_model": prep_model})

# %% [markdown]
# ## 3. Select `algorithm` and `core_model_hyper_dict`

# %% [markdown]
# The same model as implemented as in the Section "Configurable neural network" in the PyTorch tutorial [Hyperparameter Tuning  with Ray Tune](https://pytorch.org/tutorials/beginner/hyperparameter_tuning_tutorial.html) is used here. `spotPython` implements a class which is similar to the class described in the PyTorch tutorial. The class is called `Net_CIFAR10`   and is implemented in the file `netcifar10.py`. The class is imported here.
#
# Note: In addition to the class Net from the PyTorch tutorial, the class Net_CIFAR10 has additional attributes, namely:
#
# * learning rate (`lr`),
# * batchsize (`batch_size`),
# * epochs (`epochs`), and
# * k_folds (`k_folds`).
#
# Further attributes can be easily added to the class, e.g., `optimizer` or `loss_function`.

# %%
core_model = Net_CIFAR10
fun_control = add_core_model_to_fun_control(core_model=core_model,
                              fun_control=fun_control,
                              hyper_dict=TorchHyperDict,
                              filename=None)

# %% [markdown]
# ### The `hyper_dict` Hyperparameters for the Selected Algorithm

# %% [markdown]
# `spotPython` uses simple `JSON` files for the specification of the hyperparameters. The `JSON` file for the `core_model` is called `torch_hyper_dict.json`. The corresponding entries for the `Net_CIFAR10` class are shown below.
#
# ```json
# {"Net_CIFAR10":
#     {
#         "l1": {
#             "type": "int",
#             "default": 5,
#             "transform": "transform_power_2_int",
#             "lower": 2,
#             "upper": 9},
#         "l2": {
#             "type": "int",
#             "default": 5,
#             "transform": "transform_power_2_int",
#             "lower": 2,
#             "upper": 9},
#         "lr": {
#             "type": "float",
#             "default": 1e-03,
#             "transform": "None",
#             "lower": 1e-05,
#             "upper": 1e-02},
#         "batch_size": {
#             "type": "int",
#             "default": 4,
#             "transform": "transform_power_2_int",
#             "lower": 1,
#             "upper": 4},
#         "epochs": {
#                 "type": "int",
#                 "default": 3,
#                 "transform": "transform_power_2_int",
#                 "lower": 1,
#                 "upper": 4},
#         "k_folds": {
#             "type": "int",
#             "default": 2,
#             "transform": "None",
#             "lower": 2,
#             "upper": 3}
#     }
# }
# ```
#
# Each entry in the `JSON` file represents one hyperparameter with the following structure:
# `type`, `default`, `transform`, `lower`, and `upper`.

# %% [markdown]
# ### Categorical Hyperparameters

# %% [markdown]
# In contrast to Ray Tune, `spotPython` can handle numerical, boolean, and categorical hyperparameters. Since `Ray Tune` does not tune categorical hyperparameters, they are not used here. However, they can be specified in the `JSON` file in a similar way as the numerical hyperparameters as shown below:
#
# ```json
# "factor_hyperparameter": {
#     "levels": ["A", "B", "C"],
#     "type": "factor",
#     "default": "B",
#     "transform": "None",
#     "core_model_parameter_type": "str",
#     "lower": 0,
#     "upper": 2},
# ```

# %% [markdown]
# ## 4. Modify `hyper_dict` Hyperparameters for the Selected Algorithm aka `core_model`

# %% [markdown]
# After specifying the model, the corresponding hyperparameters, their types and bounds are loaded from the `JSON` file `torch_hyper_dict.json`. After loading, the user can modify the hyperparameters, e.g., the bounds.
# `spotPython` provides a clever rule for de-activating hyperparameters. If the lower and the upper bound are set to identical values, the hyperparameter is de-activated. This is useful for the hyperparameter tuning, because it allows to specify a hyperparameter in the `JSON` file, but to de-activate it in the `fun_control` dictionary. This is done in the next step.

# %% [markdown]
# ### Modify hyperparameter of type numeric and integer (boolean)
#
# Since the hyperparameter `k_folds` is not used in the PyTorch tutorial, it is de-activated here by setting the lower and upper bound to the same value.

# %%
fun_control = modify_hyper_parameter_bounds(fun_control, "k_folds", bounds=[0, 0])
fun_control["core_model_hyper_dict"]
# Out:
# {'l1': {'type': 'int',
#   'default': 5,
#   'transform': 'transform_power_2_int',
#   'lower': 2,
#   'upper': 9},
#  'l2': {'type': 'int',
#   'default': 5,
#   'transform': 'transform_power_2_int',
#   'lower': 2,
#   'upper': 9},
#  'lr': {'type': 'float',
#   'default': 0.001,
#   'transform': 'None',
#   'lower': 1e-05,
#   'upper': 0.01},
#  'batch_size': {'type': 'int',
#   'default': 4,
#   'transform': 'transform_power_2_int',
#   'lower': 1,
#   'upper': 4},
#  'epochs': {'type': 'int',
#   'default': 3,
#   'transform': 'transform_power_2_int',
#   'lower': 3,
#   'upper': 4},
#  'k_folds': {'type': 'int',
#   'default': 2,
#   'transform': 'None',
#   'lower': 0,
#   'upper': 0}}

# %% [markdown]
# ### Modify hyperparameter of type factor

# %% [markdown]
# In a similar manner as for the numerical hyperparameters, the categorical hyperparameters can be modified. For example, the hyperparameter `leaf_model` is de-activated here by choosing only one value `"LinearRegression"`.

# %%
# fun_control = modify_hyper_parameter_levels(fun_control, "leaf_model", ["LinearRegression"])

# %% [markdown]
# ## 5. Selection of the Objective (Loss) Function

# %% [markdown]
# There are two metrics:
#
#     1. `metric` is used for the river based evaluation via `eval_oml_iter_progressive`.
#     2. `metric_sklearn` is used for the sklearn based evaluation.

# %% [markdown]
# **Important**:
#
# * `spotPython` performs minimization by default.
# * If accuracy should be maximized, then the objective function has to be multiplied by -1. Therefore, `weights` is set to -1 in this case.

# %%
fun = HyperTorch(seed=123, log_level=50).fun_torch
weights = 1.0
shuffle = True
eval = "train_hold_out"
device = DEVICE

fun_control.update({
               "data_dir": None,
               "checkpoint_dir": None,
               "horizon": None,
               "oml_grace_period": None,
               "weights": weights,
               "step": None,
               "log_level": 50,
               "weight_coeff": None,
               "metric": None,
               "metric_sklearn": None,
               "shuffle": shuffle,
               "eval": eval,
               "device": device,
               })

# %% [markdown]
# ## 6. Calling the SPOT Function

# %% [markdown]
# ### Prepare the SPOT Parameters

# %% [markdown]
# * Get types and variable names as well as lower and upper bounds for the hyperparameters.

# %%
var_type = get_var_type(fun_control)
var_name = get_var_name(fun_control)
fun_control.update({"var_type": var_type,
                    "var_name": var_name})

lower = get_bound_values(fun_control, "lower")
upper = get_bound_values(fun_control, "upper")

# %%
print(gen_design_table(fun_control))
# Out:
# | name       | type   |   default |   lower |   upper | transform             |
# |------------|--------|-----------|---------|---------|-----------------------|
# | l1         | int    |     5     |   2     |    9    | transform_power_2_int |
# | l2         | int    |     5     |   2     |    9    | transform_power_2_int |
# | lr         | float  |     0.001 |   1e-05 |    0.01 | None                  |
# | batch_size | int    |     4     |   1     |    4    | transform_power_2_int |
# | epochs     | int    |     3     |   3     |    4    | transform_power_2_int |
# | k_folds    | int    |     2     |   0     |    0    | None                  |

# %% [markdown]
# ### Run the `Spot` Optimizer
#
# * Run SPOT for approx. x mins (`max_time`).
# * Note: the run takes longer, because the evaluation time of initial design (here: `initi_size`, 20 points) is not considered.

# %%
from spotPython.hyperparameters.values import get_default_hyperparameters_as_array
hyper_dict=TorchHyperDict().load()
X_start = get_default_hyperparameters_as_array(fun_control, hyper_dict)
X_start
# Out:
# array([[5.e+00, 5.e+00, 1.e-03, 4.e+00, 3.e+00, 2.e+00]])

# %%
spot_tuner = spot.Spot(fun=fun,
                   lower = lower,
                   upper = upper,
                   fun_evals = inf,
                   fun_repeats = 1,
                   max_time = MAX_TIME,
                   noise = False,
                   tolerance_x = np.sqrt(np.spacing(1)),
                   var_type = var_type,
                   var_name = var_name,
                   infill_criterion = "y",
                   n_points = 1,
                   seed=123,
                   log_level = 50,
                   show_models= False,
                   show_progress= True,
                   fun_control = fun_control,
                   design_control={"init_size": INIT_SIZE,
                                   "repeats": 1},
                   surrogate_control={"noise": True,
                                      "cod_type": "norm",
                                      "min_theta": -4,
                                      "max_theta": 3,
                                      "n_theta": len(var_name),
                                      "model_optimizer": differential_evolution,
                                      "model_fun_evals": 10_000,
                                      "log_level": 50
                                      })
spot_tuner.run(X_start=X_start)
# Out:
# Epoch: 1
# Batch:  1000. Batch Size: 4. Training Loss (running): 2.189
# Batch:  2000. Batch Size: 4. Training Loss (running): 1.010
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.650
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.472
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.364
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.289
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.246
# Loss on hold-out set: 1.6678362958431243
# Accuracy on hold-out set: 0.3455
# Epoch: 2
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.670
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.829
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.552
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.406
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.322
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.264
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.231
# Loss on hold-out set: 1.6662812544584273
# Accuracy on hold-out set: 0.40275
# Epoch: 3
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.544
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.786
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.511
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.386
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.305
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.256
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.215
# Loss on hold-out set: 1.5414324805259705
# Accuracy on hold-out set: 0.45265
# Epoch: 4
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.457
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.730
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.492
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.374
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.291
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.243
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.205
# Loss on hold-out set: 1.482014685037732
# Accuracy on hold-out set: 0.4828
# Epoch: 5
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.396
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.713
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.476
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.350
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.285
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.234
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.202
# Loss on hold-out set: 1.4764000078886748
# Accuracy on hold-out set: 0.49465
# Epoch: 6
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.324
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.665
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.461
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.344
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.273
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.226
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.195
# Loss on hold-out set: 1.5140310244716704
# Accuracy on hold-out set: 0.49055
# Epoch: 7
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.348
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.639
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.448
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.334
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.264
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.227
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.189
# Loss on hold-out set: 1.53878322924003
# Accuracy on hold-out set: 0.50535
# Epoch: 8
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.264
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.625
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.428
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.333
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.258
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.218
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.189
# Loss on hold-out set: 1.4946918760761618
# Accuracy on hold-out set: 0.51755
# Epoch: 9
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.193
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.613
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.420
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.308
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.261
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.207
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.184
# Loss on hold-out set: 1.5133872921486384
# Accuracy on hold-out set: 0.5421
# Epoch: 10
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.159
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.605
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.399
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.313
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.248
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.203
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.177
# Loss on hold-out set: 1.4576748591192066
# Accuracy on hold-out set: 0.5434
# Epoch: 11
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.141
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.589
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.384
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.296
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.234
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.199
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.174
# Loss on hold-out set: 1.5118185905493795
# Accuracy on hold-out set: 0.54435
# Epoch: 12
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.069
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.565
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.378
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.280
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.224
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.198
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.164
# Loss on hold-out set: 1.5036814422950149
# Accuracy on hold-out set: 0.55035
# Epoch: 13
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.057
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.549
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.367
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.275
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.226
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.181
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.159
# Loss on hold-out set: 1.5306338790958747
# Accuracy on hold-out set: 0.55155
# Epoch: 14
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.014
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.524
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.357
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.271
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.223
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.175
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.162
# Loss on hold-out set: 1.5399028830692172
# Accuracy on hold-out set: 0.56565
# Epoch: 15
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.004
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.526
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.342
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.254
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.208
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.173
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.155
# Loss on hold-out set: 1.596890861410834
# Accuracy on hold-out set: 0.56115
# Early stopping at epoch 14
# Returned to Spot: Validation loss: 1.596890861410834
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 16. Training Loss (running): 2.093
# Loss on hold-out set: 1.754739413356781
# Accuracy on hold-out set: 0.34385
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.695
# Loss on hold-out set: 1.5822103508472443
# Accuracy on hold-out set: 0.41785
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.537
# Loss on hold-out set: 1.4749929841041565
# Accuracy on hold-out set: 0.45765
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.432
# Loss on hold-out set: 1.4308575835227966
# Accuracy on hold-out set: 0.4809
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.359
# Loss on hold-out set: 1.3545156965732574
# Accuracy on hold-out set: 0.50675
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.297
# Loss on hold-out set: 1.3447529619216918
# Accuracy on hold-out set: 0.5209
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.251
# Loss on hold-out set: 1.261940655565262
# Accuracy on hold-out set: 0.5465
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.197
# Loss on hold-out set: 1.2382229067802428
# Accuracy on hold-out set: 0.55665
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.180
# Loss on hold-out set: 1.221636790895462
# Accuracy on hold-out set: 0.56815
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.146
# Loss on hold-out set: 1.203740731048584
# Accuracy on hold-out set: 0.57645
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.094
# Loss on hold-out set: 1.1835854142665863
# Accuracy on hold-out set: 0.5829
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.085
# Loss on hold-out set: 1.1665511705636977
# Accuracy on hold-out set: 0.587
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.059
# Loss on hold-out set: 1.160166664648056
# Accuracy on hold-out set: 0.5863
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.025
# Loss on hold-out set: 1.1407192567825317
# Accuracy on hold-out set: 0.59735
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.016
# Loss on hold-out set: 1.1416545028209686
# Accuracy on hold-out set: 0.5988
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.991
# Loss on hold-out set: 1.1268368786334992
# Accuracy on hold-out set: 0.60575
# Returned to Spot: Validation loss: 1.1268368786334992
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 4. Training Loss (running): 2.158
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.957
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.602
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.430
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.334
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.271
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.228
# Loss on hold-out set: 1.5483515374541283
# Accuracy on hold-out set: 0.43815
# Epoch: 2
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.539
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.764
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.489
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.363
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.297
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.242
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.204
# Loss on hold-out set: 1.3943005805671216
# Accuracy on hold-out set: 0.50125
# Epoch: 3
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.369
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.696
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.457
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.336
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.261
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.220
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.186
# Loss on hold-out set: 1.4334097479954362
# Accuracy on hold-out set: 0.49795
# Epoch: 4
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.244
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.617
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.415
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.309
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.255
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.206
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.176
# Loss on hold-out set: 1.2607649323098362
# Accuracy on hold-out set: 0.56115
# Epoch: 5
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.170
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.584
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.375
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.286
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.239
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.190
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.164
# Loss on hold-out set: 1.2069667365722359
# Accuracy on hold-out set: 0.5862
# Epoch: 6
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.072
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.530
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.359
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.271
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.214
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.184
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.155
# Loss on hold-out set: 1.186899975791946
# Accuracy on hold-out set: 0.5955
# Epoch: 7
# Batch:  1000. Batch Size: 4. Training Loss (running): 0.945
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.507
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.333
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.247
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.205
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.175
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.150
# Loss on hold-out set: 1.19134729722403
# Accuracy on hold-out set: 0.59815
# Epoch: 8
# Batch:  1000. Batch Size: 4. Training Loss (running): 0.909
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.473
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.313
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.232
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.190
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.153
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.143
# Loss on hold-out set: 1.2659580258307979
# Accuracy on hold-out set: 0.5927
# Returned to Spot: Validation loss: 1.2659580258307979
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 4. Training Loss (running): 2.199
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.999
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.623
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.445
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.344
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.275
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.235
# Loss on hold-out set: 1.6110808811306954
# Accuracy on hold-out set: 0.42375
# Epoch: 2
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.594
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.786
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.519
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.387
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.305
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.250
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.214
# Loss on hold-out set: 1.505294915831089
# Accuracy on hold-out set: 0.4527
# Epoch: 3
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.466
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.727
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.486
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.363
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.282
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.232
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.201
# Loss on hold-out set: 1.4007781499385834
# Accuracy on hold-out set: 0.49735
# Epoch: 4
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.376
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.679
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.456
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.338
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.270
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.226
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.188
# Loss on hold-out set: 1.3589023929804565
# Accuracy on hold-out set: 0.5203
# Epoch: 5
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.301
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.646
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.430
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.321
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.255
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.216
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.182
# Loss on hold-out set: 1.288699673768878
# Accuracy on hold-out set: 0.5493
# Epoch: 6
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.191
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.616
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.423
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.311
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.244
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.204
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.179
# Loss on hold-out set: 1.2601243545681238
# Accuracy on hold-out set: 0.5527
# Epoch: 7
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.198
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.613
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.391
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.297
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.241
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.199
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.169
# Loss on hold-out set: 1.2752042954273521
# Accuracy on hold-out set: 0.55575
# Epoch: 8
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.157
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.582
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.385
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.286
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.230
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.195
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.164
# Loss on hold-out set: 1.2737822902403773
# Accuracy on hold-out set: 0.5641
# Epoch: 9
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.102
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.560
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.377
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.276
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.224
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.189
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.162
# Loss on hold-out set: 1.211600037216395
# Accuracy on hold-out set: 0.5834
# Epoch: 10
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.087
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.557
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.370
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.277
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.215
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.185
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.154
# Loss on hold-out set: 1.1829772631533444
# Accuracy on hold-out set: 0.59325
# Epoch: 11
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.092
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.540
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.344
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.274
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.213
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.177
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.156
# Loss on hold-out set: 1.168474393489212
# Accuracy on hold-out set: 0.5973
# Epoch: 12
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.024
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.525
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.360
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.263
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.212
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.176
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.144
# Loss on hold-out set: 1.190979109909013
# Accuracy on hold-out set: 0.59495
# Epoch: 13
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.001
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.507
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.356
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.262
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.211
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.169
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.146
# Loss on hold-out set: 1.1972722633112223
# Accuracy on hold-out set: 0.5955
# Epoch: 14
# Batch:  1000. Batch Size: 4. Training Loss (running): 0.994
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.506
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.331
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.261
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.208
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.175
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.141
# Loss on hold-out set: 1.2076763573940843
# Accuracy on hold-out set: 0.59855
# Epoch: 15
# Batch:  1000. Batch Size: 4. Training Loss (running): 0.986
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.493
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.334
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.261
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.203
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.162
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.143
# Loss on hold-out set: 1.1688799539737404
# Accuracy on hold-out set: 0.61365
# Epoch: 16
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.003
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.484
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.329
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.238
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.199
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.168
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.139
# Loss on hold-out set: 1.187353637681715
# Accuracy on hold-out set: 0.6075
# Early stopping at epoch 15
# Returned to Spot: Validation loss: 1.187353637681715
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 8. Training Loss (running): 2.051
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.880
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.549
# Loss on hold-out set: 1.5504739933729172
# Accuracy on hold-out set: 0.4258
# Epoch: 2
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.538
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.740
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.475
# Loss on hold-out set: 1.3996925511360168
# Accuracy on hold-out set: 0.4988
# Epoch: 3
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.370
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.675
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.448
# Loss on hold-out set: 1.3516444100022316
# Accuracy on hold-out set: 0.52205
# Epoch: 4
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.258
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.623
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.423
# Loss on hold-out set: 1.2571390731811523
# Accuracy on hold-out set: 0.54995
# Epoch: 5
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.164
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.581
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.391
# Loss on hold-out set: 1.195084074640274
# Accuracy on hold-out set: 0.57925
# Epoch: 6
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.104
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.556
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.358
# Loss on hold-out set: 1.1803221977591514
# Accuracy on hold-out set: 0.58915
# Epoch: 7
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.034
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.521
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.341
# Loss on hold-out set: 1.1266532413333654
# Accuracy on hold-out set: 0.60805
# Epoch: 8
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.953
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.483
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.326
# Loss on hold-out set: 1.125712848752737
# Accuracy on hold-out set: 0.61635
# Epoch: 9
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.896
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.459
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.311
# Loss on hold-out set: 1.1631611384436489
# Accuracy on hold-out set: 0.6062
# Epoch: 10
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.845
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.423
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.292
# Loss on hold-out set: 1.1183801993310452
# Accuracy on hold-out set: 0.6212
# Epoch: 11
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.793
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.403
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.276
# Loss on hold-out set: 1.1693977348610758
# Accuracy on hold-out set: 0.62615
# Epoch: 12
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.712
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.375
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.259
# Loss on hold-out set: 1.1744632982075214
# Accuracy on hold-out set: 0.6205
# Epoch: 13
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.663
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.349
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.235
# Loss on hold-out set: 1.2175296401560307
# Accuracy on hold-out set: 0.61845
# Epoch: 14
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.616
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.318
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.228
# Loss on hold-out set: 1.2263264092378319
# Accuracy on hold-out set: 0.62235
# Epoch: 15
# Batch:  1000. Batch Size: 8. Training Loss (running): 0.557
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.297
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.204
# Loss on hold-out set: 1.23273256059736
# Accuracy on hold-out set: 0.62875
# Early stopping at epoch 14
# Returned to Spot: Validation loss: 1.23273256059736
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 8. Training Loss (running): 2.113
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.923
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.565
# Loss on hold-out set: 1.6561355643987656
# Accuracy on hold-out set: 0.3892
# Epoch: 2
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.574
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.779
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.504
# Loss on hold-out set: 1.4803188378214835
# Accuracy on hold-out set: 0.46905
# Epoch: 3
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.430
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.709
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.475
# Loss on hold-out set: 1.4484555087327957
# Accuracy on hold-out set: 0.48355
# Epoch: 4
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.367
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.678
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.441
# Loss on hold-out set: 1.3836431640028954
# Accuracy on hold-out set: 0.51015
# Epoch: 5
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.275
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.647
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.430
# Loss on hold-out set: 1.331129930984974
# Accuracy on hold-out set: 0.52275
# Epoch: 6
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.221
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.628
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.412
# Loss on hold-out set: 1.3059807046830654
# Accuracy on hold-out set: 0.5392
# Epoch: 7
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.207
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.607
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.399
# Loss on hold-out set: 1.3015327618181705
# Accuracy on hold-out set: 0.54345
# Epoch: 8
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.153
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.580
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.396
# Loss on hold-out set: 1.306911477059126
# Accuracy on hold-out set: 0.54805
# Epoch: 9
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.163
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.576
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.384
# Loss on hold-out set: 1.2566834417819976
# Accuracy on hold-out set: 0.5607
# Epoch: 10
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.117
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.563
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.382
# Loss on hold-out set: 1.340819655752182
# Accuracy on hold-out set: 0.5437
# Epoch: 11
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.096
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.561
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.373
# Loss on hold-out set: 1.3432154145807027
# Accuracy on hold-out set: 0.5507
# Epoch: 12
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.081
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.547
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.377
# Loss on hold-out set: 1.2140182574510574
# Accuracy on hold-out set: 0.58285
# Epoch: 13
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.059
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.543
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.370
# Loss on hold-out set: 1.2293866461277008
# Accuracy on hold-out set: 0.5807
# Epoch: 14
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.051
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.535
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.370
# Loss on hold-out set: 1.224837119320035
# Accuracy on hold-out set: 0.58435
# Epoch: 15
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.046
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.531
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.365
# Loss on hold-out set: 1.2789025944054127
# Accuracy on hold-out set: 0.5665
# Epoch: 16
# Batch:  1000. Batch Size: 8. Training Loss (running): 1.031
# Batch:  2000. Batch Size: 8. Training Loss (running): 0.525
# Batch:  3000. Batch Size: 8. Training Loss (running): 0.355
# Loss on hold-out set: 1.2613425068467856
# Accuracy on hold-out set: 0.5719
# Returned to Spot: Validation loss: 1.2613425068467856
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.981
# Loss on hold-out set: 1.66085695104599
# Accuracy on hold-out set: 0.3843
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.564
# Loss on hold-out set: 1.4716605919361114
# Accuracy on hold-out set: 0.4631
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.417
# Loss on hold-out set: 1.396134734773636
# Accuracy on hold-out set: 0.4909
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.340
# Loss on hold-out set: 1.3687958407402039
# Accuracy on hold-out set: 0.50355
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.279
# Loss on hold-out set: 1.3451326898097993
# Accuracy on hold-out set: 0.52375
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.242
# Loss on hold-out set: 1.2865592031002044
# Accuracy on hold-out set: 0.5299
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.192
# Loss on hold-out set: 1.2334594408035278
# Accuracy on hold-out set: 0.5587
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.171
# Loss on hold-out set: 1.2049515547513963
# Accuracy on hold-out set: 0.57005
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.135
# Loss on hold-out set: 1.2272026126384734
# Accuracy on hold-out set: 0.5652
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.111
# Loss on hold-out set: 1.2213460743188858
# Accuracy on hold-out set: 0.56635
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.100
# Loss on hold-out set: 1.2002300717830658
# Accuracy on hold-out set: 0.5733
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.062
# Loss on hold-out set: 1.1712953592061996
# Accuracy on hold-out set: 0.5855
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.069
# Loss on hold-out set: 1.1887342354297639
# Accuracy on hold-out set: 0.5787
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.056
# Loss on hold-out set: 1.1772706559419632
# Accuracy on hold-out set: 0.5865
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.034
# Loss on hold-out set: 1.1763498730897903
# Accuracy on hold-out set: 0.59125
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.033
# Loss on hold-out set: 1.2205276499986648
# Accuracy on hold-out set: 0.57265
# Returned to Spot: Validation loss: 1.2205276499986648
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 2. Training Loss (running): 2.139
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.976
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.616
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.442
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.346
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.285
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.242
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.201
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.174
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.163
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.146
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.134
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.117
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.111
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.101
# Loss on hold-out set: 1.5267292144278763
# Accuracy on hold-out set: 0.47835
# Epoch: 2
# Batch:  1000. Batch Size: 2. Training Loss (running): 1.496
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.731
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.505
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.369
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.292
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.243
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.210
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.176
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.162
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.142
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.131
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.118
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.109
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.100
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.094
# Loss on hold-out set: 1.4535494465552832
# Accuracy on hold-out set: 0.512
# Epoch: 3
# Batch:  1000. Batch Size: 2. Training Loss (running): 1.344
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.678
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.448
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.348
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.268
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.227
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.187
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.164
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.143
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.135
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.115
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.108
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.102
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.093
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.085
# Loss on hold-out set: 1.3406006316455699
# Accuracy on hold-out set: 0.5661
# Epoch: 4
# Batch:  1000. Batch Size: 2. Training Loss (running): 1.163
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.640
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.406
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.306
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.244
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.208
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.178
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.154
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.138
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.121
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.109
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.103
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.095
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.089
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.079
# Loss on hold-out set: 1.4402095039898206
# Accuracy on hold-out set: 0.5832
# Epoch: 5
# Batch:  1000. Batch Size: 2. Training Loss (running): 1.098
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.552
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.369
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.273
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.224
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.188
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.157
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.145
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.128
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.113
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.106
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.096
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.088
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.082
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.081
# Loss on hold-out set: 1.4124941594799516
# Accuracy on hold-out set: 0.598
# Epoch: 6
# Batch:  1000. Batch Size: 2. Training Loss (running): 0.940
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.474
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.332
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.253
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.200
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.180
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.149
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.134
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.119
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.104
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.096
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.087
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.090
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.079
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.068
# Loss on hold-out set: 1.6996587575286133
# Accuracy on hold-out set: 0.5809
# Epoch: 7
# Batch:  1000. Batch Size: 2. Training Loss (running): 0.919
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.424
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.297
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.232
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.182
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.166
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.134
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.117
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.104
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.098
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.085
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.078
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.076
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.073
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.069
# Loss on hold-out set: 1.7193671714203673
# Accuracy on hold-out set: 0.5971
# Epoch: 8
# Batch:  1000. Batch Size: 2. Training Loss (running): 0.733
# Batch:  2000. Batch Size: 2. Training Loss (running): 0.388
# Batch:  3000. Batch Size: 2. Training Loss (running): 0.284
# Batch:  4000. Batch Size: 2. Training Loss (running): 0.209
# Batch:  5000. Batch Size: 2. Training Loss (running): 0.178
# Batch:  6000. Batch Size: 2. Training Loss (running): 0.144
# Batch:  7000. Batch Size: 2. Training Loss (running): 0.119
# Batch:  8000. Batch Size: 2. Training Loss (running): 0.114
# Batch:  9000. Batch Size: 2. Training Loss (running): 0.096
# Batch: 10000. Batch Size: 2. Training Loss (running): 0.090
# Batch: 11000. Batch Size: 2. Training Loss (running): 0.079
# Batch: 12000. Batch Size: 2. Training Loss (running): 0.068
# Batch: 13000. Batch Size: 2. Training Loss (running): 0.069
# Batch: 14000. Batch Size: 2. Training Loss (running): 0.063
# Batch: 15000. Batch Size: 2. Training Loss (running): 0.060
# Loss on hold-out set: 2.037941264964526
# Accuracy on hold-out set: 0.5981
# Early stopping at epoch 7
# Returned to Spot: Validation loss: 2.037941264964526
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 4. Training Loss (running): 2.099
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.952
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.591
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.414
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.327
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.258
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.224
# Loss on hold-out set: 1.4976244003474712
# Accuracy on hold-out set: 0.45615
# Epoch: 2
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.484
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.724
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.469
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.352
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.283
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.227
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.201
# Loss on hold-out set: 1.3426306402802468
# Accuracy on hold-out set: 0.51665
# Epoch: 3
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.277
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.643
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.437
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.326
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.255
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.208
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.182
# Loss on hold-out set: 1.2569977641530334
# Accuracy on hold-out set: 0.56485
# Epoch: 4
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.163
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.595
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.399
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.298
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.237
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.203
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.170
# Loss on hold-out set: 1.3227899159120047
# Accuracy on hold-out set: 0.55465
# Epoch: 5
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.097
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.554
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.376
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.278
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.220
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.190
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.160
# Loss on hold-out set: 1.3215095737829805
# Accuracy on hold-out set: 0.5642
# Epoch: 6
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.002
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.498
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.358
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.266
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.210
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.173
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.149
# Loss on hold-out set: 1.2438121337476897
# Accuracy on hold-out set: 0.5934
# Epoch: 7
# Batch:  1000. Batch Size: 4. Training Loss (running): 0.955
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.493
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.326
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.247
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.199
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.165
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.143
# Loss on hold-out set: 1.2268427195775322
# Accuracy on hold-out set: 0.60455
# Epoch: 8
# Batch:  1000. Batch Size: 4. Training Loss (running): 0.881
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.436
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.293
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.240
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.187
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.164
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.138
# Loss on hold-out set: 1.2487638950954425
# Accuracy on hold-out set: 0.6047
# Returned to Spot: Validation loss: 1.2487638950954425
# ----------------------------------------------
# Epoch: 1
# Batch:  1000. Batch Size: 4. Training Loss (running): 2.305
# Batch:  2000. Batch Size: 4. Training Loss (running): 1.075
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.677
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.491
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.386
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.310
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.261
# Loss on hold-out set: 1.8095878218770027
# Accuracy on hold-out set: 0.32135
# Epoch: 2
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.789
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.865
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.569
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.427
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.337
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.275
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.234
# Loss on hold-out set: 1.6328504878401757
# Accuracy on hold-out set: 0.395
# Epoch: 3
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.629
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.804
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.523
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.399
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.314
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.259
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.223
# Loss on hold-out set: 1.5376390185058117
# Accuracy on hold-out set: 0.43535
# Epoch: 4
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.517
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.765
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.511
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.378
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.302
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.245
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.212
# Loss on hold-out set: 1.475802092206478
# Accuracy on hold-out set: 0.4764
# Epoch: 5
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.457
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.735
# Batch:  3000. Batch Size: 4. Training Loss (running): 0.479
# Batch:  4000. Batch Size: 4. Training Loss (running): 0.358
# Batch:  5000. Batch Size: 4. Training Loss (running): 0.288
# Batch:  6000. Batch Size: 4. Training Loss (running): 0.239
# Batch:  7000. Batch Size: 4. Training Loss (running): 0.201
# Loss on hold-out set: 1.4301042360395193
# Accuracy on hold-out set: 0.48865
# Epoch: 6
# Batch:  1000. Batch Size: 4. Training Loss (running): 1.398
# Batch:  2000. Batch Size: 4. Training Loss (running): 0.708
# ...
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.090
# Loss on hold-out set: 1.1922744421243667
# Accuracy on hold-out set: 0.58655
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.050
# Loss on hold-out set: 1.1338690462112426
# Accuracy on hold-out set: 0.6064
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.002
# Loss on hold-out set: 1.1258056417226792
# Accuracy on hold-out set: 0.612
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.987
# Loss on hold-out set: 1.1376495146751404
# Accuracy on hold-out set: 0.6083
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.941
# Loss on hold-out set: 1.1640511639118194
# Accuracy on hold-out set: 0.6039
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.907
# Loss on hold-out set: 1.1025405005216597
# Accuracy on hold-out set: 0.623
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.872
# Loss on hold-out set: 1.086522045993805
# Accuracy on hold-out set: 0.6296
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.833
# Loss on hold-out set: 1.1016984593629837
# Accuracy on hold-out set: 0.62715
# Returned to Spot: Validation loss: 1.1016984593629837
# ----------------------------------------------
# Epoch: 1on tuning: [########--] 78.81%
# Batch:  1000. Batch Size: 16. Training Loss (running): 2.069
# Loss on hold-out set: 1.656296725177765
# Accuracy on hold-out set: 0.3935
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.600
# Loss on hold-out set: 1.5924991751194
# Accuracy on hold-out set: 0.41985
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.511
# Loss on hold-out set: 1.4379092189311982
# Accuracy on hold-out set: 0.4793
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.425
# Loss on hold-out set: 1.3956838734149932
# Accuracy on hold-out set: 0.4993
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.345
# Loss on hold-out set: 1.3476606277465821
# Accuracy on hold-out set: 0.5146
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.280
# Loss on hold-out set: 1.282554264974594
# Accuracy on hold-out set: 0.5404
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.209
# Loss on hold-out set: 1.2938669285297393
# Accuracy on hold-out set: 0.53875
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.177
# Loss on hold-out set: 1.2049304274082184
# Accuracy on hold-out set: 0.573
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.119
# Loss on hold-out set: 1.2218334283351897
# Accuracy on hold-out set: 0.56995
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.071
# Loss on hold-out set: 1.2003751665592193
# Accuracy on hold-out set: 0.5763
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.035
# Loss on hold-out set: 1.162038119673729
# Accuracy on hold-out set: 0.5931
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.992
# Loss on hold-out set: 1.1578449054479598
# Accuracy on hold-out set: 0.5944
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.963
# Loss on hold-out set: 1.1644681480407715
# Accuracy on hold-out set: 0.5998
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.932
# Loss on hold-out set: 1.1351766295433043
# Accuracy on hold-out set: 0.60695
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.895
# Loss on hold-out set: 1.1675695649504663
# Accuracy on hold-out set: 0.5988
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.865
# Loss on hold-out set: 1.1374941776275636
# Accuracy on hold-out set: 0.61785
# Returned to Spot: Validation loss: 1.1374941776275636
# ----------------------------------------------
# Epoch: 1on tuning: [########--] 83.31%
# Batch:  1000. Batch Size: 16. Training Loss (running): 2.071
# Loss on hold-out set: 1.6882117435455322
# Accuracy on hold-out set: 0.38965
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.601
# Loss on hold-out set: 1.494446988630295
# Accuracy on hold-out set: 0.4529
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.466
# Loss on hold-out set: 1.4061405285835267
# Accuracy on hold-out set: 0.4977
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.362
# Loss on hold-out set: 1.3250476938247682
# Accuracy on hold-out set: 0.5292
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.285
# Loss on hold-out set: 1.2678996840000152
# Accuracy on hold-out set: 0.5479
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.217
# Loss on hold-out set: 1.2491638291835785
# Accuracy on hold-out set: 0.5589
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.174
# Loss on hold-out set: 1.2265664418935776
# Accuracy on hold-out set: 0.57105
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.126
# Loss on hold-out set: 1.1826245729923248
# Accuracy on hold-out set: 0.5846
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.086
# Loss on hold-out set: 1.1613608986854553
# Accuracy on hold-out set: 0.5906
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.061
# Loss on hold-out set: 1.1212425409555435
# Accuracy on hold-out set: 0.608
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.034
# Loss on hold-out set: 1.1492962419509887
# Accuracy on hold-out set: 0.6021
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.990
# Loss on hold-out set: 1.1852734377145768
# Accuracy on hold-out set: 0.58415
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.951
# Loss on hold-out set: 1.1461732542276382
# Accuracy on hold-out set: 0.6024
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.918
# Loss on hold-out set: 1.1151326550006866
# Accuracy on hold-out set: 0.61155
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.902
# Loss on hold-out set: 1.1110179497480392
# Accuracy on hold-out set: 0.6182
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.866
# Loss on hold-out set: 1.124557681107521
# Accuracy on hold-out set: 0.6166
# Returned to Spot: Validation loss: 1.124557681107521
# ----------------------------------------------
# Epoch: 1on tuning: [#########-] 86.85%
# Batch:  1000. Batch Size: 16. Training Loss (running): 2.008
# Loss on hold-out set: 1.6345982231140137
# Accuracy on hold-out set: 0.40145
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.579
# Loss on hold-out set: 1.5013457566738129
# Accuracy on hold-out set: 0.4543
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.458
# Loss on hold-out set: 1.4247602716445922
# Accuracy on hold-out set: 0.48575
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.378
# Loss on hold-out set: 1.3651839794635772
# Accuracy on hold-out set: 0.5101
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.300
# Loss on hold-out set: 1.3382831794261933
# Accuracy on hold-out set: 0.5278
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.224
# Loss on hold-out set: 1.2551363802909852
# Accuracy on hold-out set: 0.5554
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.172
# Loss on hold-out set: 1.2702233959913254
# Accuracy on hold-out set: 0.5538
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.117
# Loss on hold-out set: 1.185893332505226
# Accuracy on hold-out set: 0.58365
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.088
# Loss on hold-out set: 1.1873647486209868
# Accuracy on hold-out set: 0.5817
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.041
# Loss on hold-out set: 1.2177131325244903
# Accuracy on hold-out set: 0.57795
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.997
# Loss on hold-out set: 1.1705777745485306
# Accuracy on hold-out set: 0.5961
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.970
# Loss on hold-out set: 1.1269281531572342
# Accuracy on hold-out set: 0.60765
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.926
# Loss on hold-out set: 1.1616385493755341
# Accuracy on hold-out set: 0.59885
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.894
# Loss on hold-out set: 1.1689747166872024
# Accuracy on hold-out set: 0.60295
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.867
# Loss on hold-out set: 1.1553476363182067
# Accuracy on hold-out set: 0.60615
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.829
# Loss on hold-out set: 1.1445833217740058
# Accuracy on hold-out set: 0.61415
# Returned to Spot: Validation loss: 1.1445833217740058
# ----------------------------------------------
# Epoch: 1on tuning: [#########-] 90.55%
# Batch:  1000. Batch Size: 16. Training Loss (running): 2.043
# Loss on hold-out set: 1.5792454117774963
# Accuracy on hold-out set: 0.41755
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.572
# Loss on hold-out set: 1.4558889817237854
# Accuracy on hold-out set: 0.47425
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.444
# Loss on hold-out set: 1.3848632689952851
# Accuracy on hold-out set: 0.49795
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.359
# Loss on hold-out set: 1.3554592038154603
# Accuracy on hold-out set: 0.5136
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.285
# Loss on hold-out set: 1.328146096420288
# Accuracy on hold-out set: 0.52095
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.236
# Loss on hold-out set: 1.2470461691379546
# Accuracy on hold-out set: 0.555
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.190
# Loss on hold-out set: 1.2466919558048248
# Accuracy on hold-out set: 0.5583
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.139
# Loss on hold-out set: 1.2161012953281403
# Accuracy on hold-out set: 0.5716
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.103
# Loss on hold-out set: 1.149646456837654
# Accuracy on hold-out set: 0.59665
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.051
# Loss on hold-out set: 1.1311574947118759
# Accuracy on hold-out set: 0.60255
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.021
# Loss on hold-out set: 1.1311592679977418
# Accuracy on hold-out set: 0.6041
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.986
# Loss on hold-out set: 1.1515342775583268
# Accuracy on hold-out set: 0.59915
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.955
# Loss on hold-out set: 1.1409016694545746
# Accuracy on hold-out set: 0.6075
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.927
# Loss on hold-out set: 1.1235749183654786
# Accuracy on hold-out set: 0.6144
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.892
# Loss on hold-out set: 1.106348890376091
# Accuracy on hold-out set: 0.62005
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.864
# Loss on hold-out set: 1.1063217545628548
# Accuracy on hold-out set: 0.6246
# Returned to Spot: Validation loss: 1.1063217545628548
# ----------------------------------------------
# Epoch: 1on tuning: [#########-] 94.23%
# Batch:  1000. Batch Size: 16. Training Loss (running): 2.028
# Loss on hold-out set: 1.65677916431427
# Accuracy on hold-out set: 0.39345
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.622
# Loss on hold-out set: 1.5134518872261047
# Accuracy on hold-out set: 0.45115
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.488
# Loss on hold-out set: 1.4397063151836396
# Accuracy on hold-out set: 0.48245
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.382
# Loss on hold-out set: 1.3540849361419678
# Accuracy on hold-out set: 0.516
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.306
# Loss on hold-out set: 1.3410437579631806
# Accuracy on hold-out set: 0.5204
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.242
# Loss on hold-out set: 1.3445298326015473
# Accuracy on hold-out set: 0.5232
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.186
# Loss on hold-out set: 1.2507617936849593
# Accuracy on hold-out set: 0.55665
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.135
# Loss on hold-out set: 1.2169708014965057
# Accuracy on hold-out set: 0.5679
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.096
# Loss on hold-out set: 1.2181330315113068
# Accuracy on hold-out set: 0.57305
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.052
# Loss on hold-out set: 1.1624456652164459
# Accuracy on hold-out set: 0.5929
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.005
# Loss on hold-out set: 1.161600983786583
# Accuracy on hold-out set: 0.59495
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.982
# Loss on hold-out set: 1.1518178755283355
# Accuracy on hold-out set: 0.6019
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.943
# Loss on hold-out set: 1.1377673408985138
# Accuracy on hold-out set: 0.6095
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.910
# Loss on hold-out set: 1.1442705837965013
# Accuracy on hold-out set: 0.60865
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.884
# Loss on hold-out set: 1.164303352022171
# Accuracy on hold-out set: 0.6076
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.843
# Loss on hold-out set: 1.1570800117492677
# Accuracy on hold-out set: 0.60975
# Returned to Spot: Validation loss: 1.1570800117492677
# ----------------------------------------------
# Epoch: 1on tuning: [##########] 98.37%
# Batch:  1000. Batch Size: 16. Training Loss (running): 2.016
# Loss on hold-out set: 1.6182078249931335
# Accuracy on hold-out set: 0.40995
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.554
# Loss on hold-out set: 1.4775579141616821
# Accuracy on hold-out set: 0.4655
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.443
# Loss on hold-out set: 1.3996838124752045
# Accuracy on hold-out set: 0.4937
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.353
# Loss on hold-out set: 1.3333809238433838
# Accuracy on hold-out set: 0.5261
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.277
# Loss on hold-out set: 1.3327716420650482
# Accuracy on hold-out set: 0.5256
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.221
# Loss on hold-out set: 1.2441859623432159
# Accuracy on hold-out set: 0.56005
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.175
# Loss on hold-out set: 1.2165106500148772
# Accuracy on hold-out set: 0.5702
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.126
# Loss on hold-out set: 1.1952023577213287
# Accuracy on hold-out set: 0.58155
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.092
# Loss on hold-out set: 1.1986008540391921
# Accuracy on hold-out set: 0.5802
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.051
# Loss on hold-out set: 1.1637679537773131
# Accuracy on hold-out set: 0.59585
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.025
# Loss on hold-out set: 1.1781536458015442
# Accuracy on hold-out set: 0.59195
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.983
# Loss on hold-out set: 1.177173513507843
# Accuracy on hold-out set: 0.59235
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.952
# Loss on hold-out set: 1.1314814142942429
# Accuracy on hold-out set: 0.61085
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.920
# Loss on hold-out set: 1.1536492161512375
# Accuracy on hold-out set: 0.60335
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.887
# Loss on hold-out set: 1.134899591755867
# Accuracy on hold-out set: 0.61155
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.865
# Loss on hold-out set: 1.160164208340645
# Accuracy on hold-out set: 0.609
# Returned to Spot: Validation loss: 1.160164208340645
# ----------------------------------------------
# spotPython tuning: [##########] 100.00% Done...

# %% [markdown]
# ### 4 Results

# %%
SAVE = False
LOAD = False

if SAVE:
    result_file_name = "res_" + experiment_name + ".pkl"
    with open(result_file_name, 'wb') as f:
        pickle.dump(spot_tuner, f)

if LOAD:
    result_file_name = "res_ch10-friedman-hpt-0_maans03_60min_20init_1K_2023-04-14_10-11-19.pkl"
    with open(result_file_name, 'rb') as f:
        spot_tuner =  pickle.load(f)

# %% [markdown]
# * Show the Progress of the hyperparameter tuning:

# %%
spot_tuner.plot_progress(log_y=False, filename="../Figures.d/" + experiment_name+"_progress.pdf")

# %% [markdown]
# * Print the Results

# %%
print(gen_design_table(fun_control=fun_control, spot=spot_tuner))
# Out:
# | name       | type   |   default |   lower |   upper |                tuned | transform             |   importance | stars   |
# |------------|--------|-----------|---------|---------|----------------------|-----------------------|--------------|---------|
# | l1         | int    |       5.0 |     2.0 |     9.0 |                  7.0 | transform_power_2_int |         0.43 | .       |
# | l2         | int    |       5.0 |     2.0 |     9.0 |                  9.0 | transform_power_2_int |         0.06 |         |
# | lr         | float  |     0.001 |   1e-05 |    0.01 | 0.004493906152324669 | None                  |         2.56 | *       |
# | batch_size | int    |       4.0 |     1.0 |     4.0 |                  4.0 | transform_power_2_int |         0.33 | .       |
# | epochs     | int    |       3.0 |     3.0 |     4.0 |                  4.0 | transform_power_2_int |       100.00 | ***     |
# | k_folds    | int    |       2.0 |     0.0 |     0.0 |                  0.0 | None                  |              |         |

# %% [markdown]
# ## Show variable importance

# %%
spot_tuner.plot_importance(threshold=0.025, filename="../Figures.d/" + experiment_name+"_importance.pdf")

# %% [markdown]
# ## Get Default Hyperparameters

# %%
values_default = get_default_values(fun_control)
values_default = transform_hyper_parameter_values(fun_control=fun_control, hyper_parameter_values=values_default)
values_default
# Out:
# {'l1': 32, 'l2': 32, 'lr': 0.001, 'batch_size': 16, 'epochs': 8, 'k_folds': 2}

# %%
model_default = fun_control["core_model"](**values_default)
model_default
# Out:
# Net_CIFAR10(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=10, bias=True)
# )

# %% [markdown]
# ## Get SPOT Results

# %%
X = spot_tuner.to_all_dim(spot_tuner.min_X.reshape(1,-1))
print(X)
# Out:
# [[7.00000000e+00 9.00000000e+00 4.49390615e-03 4.00000000e+00
#   4.00000000e+00 0.00000000e+00]]

# %%
v_dict = assign_values(X, fun_control["var_name"])
return_conf_list_from_var_dict(var_dict=v_dict, fun_control=fun_control)
# Out:
# [{'l1': 128,
#   'l2': 512,
#   'lr': 0.004493906152324669,
#   'batch_size': 16,
#   'epochs': 16,
#   'k_folds': 0}]

# %%
model_spot = get_one_core_model_from_X(X, fun_control)
model_spot
# Out:
# Net_CIFAR10(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ## Test Set Accuracy

# %%
testset = fun_control["test"]
testset.data.shape
# Out:
# (10000, 32, 32, 3)

# %%
model_default.evaluate_hold_out(dataset = testset, shuffle=False)
# Out:
# Epoch: 1
# Loss on hold-out set: 2.302918875694275
# Accuracy on hold-out set: 0.1015
# Epoch: 2
# Loss on hold-out set: 2.297055534362793
# Accuracy on hold-out set: 0.13575
# Epoch: 3
# Loss on hold-out set: 2.2668219423294067
# Accuracy on hold-out set: 0.17525
# Epoch: 4
# Loss on hold-out set: 2.154258277416229
# Accuracy on hold-out set: 0.20775
# Epoch: 5
# Loss on hold-out set: 2.069060855388641
# Accuracy on hold-out set: 0.227
# Epoch: 6
# Loss on hold-out set: 2.015239537239075
# Accuracy on hold-out set: 0.25675
# Epoch: 7
# Loss on hold-out set: 1.9769464359283446
# Accuracy on hold-out set: 0.28275
# Epoch: 8
# Loss on hold-out set: 1.9454538822174072
# Accuracy on hold-out set: 0.29925
# Returned to Spot: Validation loss: 1.9454538822174072
# ----------------------------------------------
# (1.9454538822174072, nan)

# %%
model_spot.evaluate_hold_out(dataset = testset, shuffle=False)
# Out:
# Epoch: 1
# Loss on hold-out set: 2.033073651313782
# Accuracy on hold-out set: 0.2185
# Epoch: 2
# Loss on hold-out set: 1.8688571624755859
# Accuracy on hold-out set: 0.3145
# Epoch: 3
# Loss on hold-out set: 1.7738189878463746
# Accuracy on hold-out set: 0.341
# Epoch: 4
# Loss on hold-out set: 1.6966188797950745
# Accuracy on hold-out set: 0.36275
# Epoch: 5
# Loss on hold-out set: 1.6451260614395142
# Accuracy on hold-out set: 0.38625
# Epoch: 6
# Loss on hold-out set: 1.6090725727081299
# Accuracy on hold-out set: 0.404
# Epoch: 7
# Loss on hold-out set: 1.5787619414329528
# Accuracy on hold-out set: 0.422
# Epoch: 8
# Loss on hold-out set: 1.5511184277534484
# Accuracy on hold-out set: 0.433
# Epoch: 9
# Loss on hold-out set: 1.5290223169326782
# Accuracy on hold-out set: 0.44325
# Epoch: 10
# Loss on hold-out set: 1.5109457330703735
# Accuracy on hold-out set: 0.45075
# Epoch: 11
# Loss on hold-out set: 1.496400911092758
# Accuracy on hold-out set: 0.45825
# Epoch: 12
# Loss on hold-out set: 1.4829036648273468
# Accuracy on hold-out set: 0.46425
# Epoch: 13
# Loss on hold-out set: 1.4699827318191527
# Accuracy on hold-out set: 0.47
# Epoch: 14
# Loss on hold-out set: 1.4602194046974182
# Accuracy on hold-out set: 0.47425
# Epoch: 15
# Loss on hold-out set: 1.4504035742282868
# Accuracy on hold-out set: 0.4775
# Epoch: 16
# Loss on hold-out set: 1.443590271949768
# Accuracy on hold-out set: 0.4805
# Returned to Spot: Validation loss: 1.443590271949768
# ----------------------------------------------
# (1.443590271949768, nan)

# %% [markdown]
# ## Train on Train Data and Test on Test Data (Hold-Out)
#
# Final Evaluation as in the Pytorch tutorial [Hyperparameter Tuning  with Ray Tune](https://pytorch.org/tutorials/beginner/hyperparameter_tuning_tutorial.html).

# %%
trainset = fun_control["train"]

# %%
model_default.evaluate_hold_out(dataset=trainset, shuffle=False, test_dataset=testset)
# Out:
# Epoch: 1
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.922
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.930
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.610
# Loss on hold-out set: 1.7867522619247436
# Accuracy on hold-out set: 0.3453
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.785
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.872
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.580
# Loss on hold-out set: 1.7030356588363647
# Accuracy on hold-out set: 0.3662
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.706
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.831
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.554
# Loss on hold-out set: 1.6251155374526978
# Accuracy on hold-out set: 0.3988
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.623
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.789
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.531
# Loss on hold-out set: 1.5659781480789186
# Accuracy on hold-out set: 0.4291
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.558
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.759
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.515
# Loss on hold-out set: 1.5230254475593568
# Accuracy on hold-out set: 0.4461
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.514
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.739
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.504
# Loss on hold-out set: 1.4915275074005128
# Accuracy on hold-out set: 0.4576
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.481
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.724
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.496
# Loss on hold-out set: 1.4663091762542724
# Accuracy on hold-out set: 0.4692
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.455
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.712
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.488
# Loss on hold-out set: 1.4443522331237792
# Accuracy on hold-out set: 0.477
# Returned to Spot: Validation loss: 1.4443522331237792
# ----------------------------------------------
# (1.4443522331237792, nan)

# %%
model_spot.evaluate_hold_out(dataset=trainset, shuffle=False, test_dataset=testset)
# Out:
# Epoch: 1
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.427
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.678
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.451
# Loss on hold-out set: 1.3018572015285492
# Accuracy on hold-out set: 0.5308
# Epoch: 2
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.286
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.619
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.416
# Loss on hold-out set: 1.223252138185501
# Accuracy on hold-out set: 0.5627
# Epoch: 3
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.198
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.581
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.392
# Loss on hold-out set: 1.1667938819885253
# Accuracy on hold-out set: 0.5838
# Epoch: 4
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.132
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.551
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.373
# Loss on hold-out set: 1.1348598028182983
# Accuracy on hold-out set: 0.6008
# Epoch: 5
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.080
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.527
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.357
# Loss on hold-out set: 1.1067075982570649
# Accuracy on hold-out set: 0.6097
# Epoch: 6
# Batch:  1000. Batch Size: 16. Training Loss (running): 1.034
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.506
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.343
# Loss on hold-out set: 1.0904577442646026
# Accuracy on hold-out set: 0.6168
# Epoch: 7
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.994
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.487
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.330
# Loss on hold-out set: 1.071523888540268
# Accuracy on hold-out set: 0.6237
# Epoch: 8
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.957
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.471
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.318
# Loss on hold-out set: 1.0579889532089233
# Accuracy on hold-out set: 0.6312
# Epoch: 9
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.923
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.455
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.306
# Loss on hold-out set: 1.0480933242321013
# Accuracy on hold-out set: 0.6368
# Epoch: 10
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.892
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.440
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.295
# Loss on hold-out set: 1.0427774836063386
# Accuracy on hold-out set: 0.6398
# Epoch: 11
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.862
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.425
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.285
# Loss on hold-out set: 1.0419455082416536
# Accuracy on hold-out set: 0.6451
# Epoch: 12
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.832
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.411
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.276
# Loss on hold-out set: 1.0443780737400055
# Accuracy on hold-out set: 0.6457
# Epoch: 13
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.805
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.398
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.266
# Loss on hold-out set: 1.0411214764595031
# Accuracy on hold-out set: 0.6476
# Epoch: 14
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.777
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.384
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.257
# Loss on hold-out set: 1.0481536105155944
# Accuracy on hold-out set: 0.6508
# Epoch: 15
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.750
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.371
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.248
# Loss on hold-out set: 1.0553016890764237
# Accuracy on hold-out set: 0.6513
# Epoch: 16
# Batch:  1000. Batch Size: 16. Training Loss (running): 0.725
# Batch:  2000. Batch Size: 16. Training Loss (running): 0.359
# Batch:  3000. Batch Size: 16. Training Loss (running): 0.239
# Loss on hold-out set: 1.0693633296966554
# Accuracy on hold-out set: 0.6507
# Returned to Spot: Validation loss: 1.0693633296966554
# ----------------------------------------------
# (1.0693633296966554, nan)

# %% [markdown]
# ## Detailed Hyperparameter Plots

# %% [markdown]
# * For productive use, you might want to select:
#   * `min_z=min(spot_tuner.y)` and
#   * `max_z = max(spot_tuner.y)`
# * These settings are not so colorful as visualizations that use `None` for the ranges, but give better insights.

# %%
threshold = 0.025
impo = spot_tuner.print_importance(threshold=threshold, print_screen=True)
var_plots = [i for i, x in enumerate(impo) if x[1] > threshold]
min_z = min(spot_tuner.y)
max_z = max(spot_tuner.y)
n = spot_tuner.k
for i in var_plots:
    for j in var_plots:
        if j > i:
            filename = "../Figures.d/" + experiment_name+"_contour_"+str(i)+"_"+str(j)+".pdf"
            spot_tuner.plot_contour(i=i, j=j, min_z=min_z, max_z = max_z, filename=filename)
# Out:
# l1:  0.427299404776592
# l2:  0.056181834455119546
# lr:  2.562444185646454
# batch_size:  0.3279272691310497
# epochs:  100.0

# %% [markdown]
# ## Parallel Coordinates Plot

# %%
spot_tuner.parallel_plot()

# %% [markdown]
# ## Plot all Combinations of Hyperparameters
#
# * Warning: this may take a while.

# %%
PLOT_ALL = False
if PLOT_ALL:
    n = spot_tuner.k
    for i in range(n-1):
        for j in range(i+1, n):
            spot_tuner.plot_contour(i=i, j=j, min_z=min_z, max_z = max_z)
